# %% [markdown]
# <a href="https://colab.research.google.com/github/nisha0697/EDA-Booking.com---Hotel-Booking-Analysis/blob/main/EDA_Booking_com_Hotel_Booking_Analysis_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -  **Booking.com - Hotel Booking Analysis**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Team
# ##### **Team Member 1 -** Nisha Rajput
# ##### **Team Member 2 -** Kavinkumar Elango

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project aims to analyze the hotel booking dataset from Booking.com to extract valuable insights that can help optimize revenue, reduce cancellations, and improve overall customer satisfaction.
#
# First we look at the dataset and know its columns and their data types. Identify the number of duplicate values and missing values.
#
# Then our analysis begins with data wrangling where missing values, outliers and duplicate values in the dataset are handled. Columns such as children, country, agent and company have missing data which are addressed by imputations.
#
# For lead time and adr columns outliers are identified using box plot and then handled using IQR method.
#
# Then, we aggregate some columns in the dataset to find some insights. For example - finding the average lead time for each reserved room type, finding top countries based on bookings, cancellation for different market segments and much more. Also, we have written all the manipulation done in the data aggregation and found insights.
#
# After this, we have done data visualization for univariate analysis, bivariate analysis and multivariate analysis.
#
# In univariate analysis, finding the distribution of variables like room types, reservation status, lead time and customer type using bar chart, pie chart, histogram plot and count plot. Also, we have used word cloud to visualize the countries with more bookings.
#
# In bivariate analysis, finding the relationships between variables such as reserved room type and assigned room type, room type and averaged lead time, reservation status and lead time and many more using heatmap, bar chart, box plot etc.
#
# In multivariate analysis, finding the relationship between multiple variables at once. For example, analyzing how  lead time, adr, and days in the waiting list interact with each other based on reservation status using pair plots.
#
# Also, we have written the insights found from the visualization and their business impacts.
#
# Finally, we have given the solutions to the business objective and the conclusion.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Hotel business is one of the most competitive business, Reducing cancellations and maintaining long term customers are important parts in hotel business.
# Hotel booking plays vital role while planing a trip and due to lot of competitors it makes customers confused. Providing best offers
# and knowing suitable complimentaries for each type of customer is crucial.
# With both of this big giants hotel business also faces additional major issue that it is an seasonal business and need to maintain revenue
# even in non seasonal months.
# In order to maintain this all things business needs to analyse the data and know meaningfull insights from those is important.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
#   increase revenue, reduce cacellations, predict guest preferences

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
import warnings
warnings.filterwarnings("ignore", category=FutureWarning) # handling Future warning error which we can't eliminate due to collab not supporting newer python version
# %matplotlib inline

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
filepath = "Hotel Bookings.csv"
booking_df = pd.read_csv(filepath)

# %%
booking_df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# ### Dataset First View

# %%
# Top 5 rows
booking_df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
# last 5 rows
booking_df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset size
booking_df.shape
# Out:
# (119390, 32)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
booking_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
booking_df.duplicated().sum()
# Out:
# 31994

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
booking_df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# Visualizing the missing values
sns.heatmap(booking_df.isnull(), cbar = False)
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# This dataset contains booking.com's booking data for year 2015 to 2017.
# Using this datas we can get to know which type of hotels are doing good and what are the points requires actions. We may provide meaningfull trends and relationship between some categories and so on.
#
#
# This contains 119390 rows and 32 columns which includes 31994 duplicate rows.
# children, country, agent and company columns haves missing/Nan values too, so this dataset needs a hard cleaning before doing analysis with this.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
booking_df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
booking_df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# •	**hotel** : Defining whether the hotel is Resort Hotel or City Hotel (Categorical data)
#
# •	**is_cancelled** : Mentioning the booking is cancelled or not (Categorical data)
#
# •	**lead_time** : Number of days that elapsed between the entering date of the booking into the PMS and the arrival date
#
# •	**arrival_date_year** : Contains year when the booking is done and values are between 2015 and 2017
#
# •	**arrival_date_month** : Contains month when the booking is done
#
# •	**arrival_date_week_number** : Week number of particular year while arriving
#
# •	**arrival_date_day_of_month** : Date of arrival to hotel
#
# •	**stays_in_weekend_nights** : Number of nights stayed in weekends
#
# •	**stays_in_week_nights** : Number of nights stayed in weekdays
#
# •	**adults** : Number of adults
#
# •	**children** : Number of childrens
#
# •	**babies** :  Number of babies
#
# •	**meal** : Kind of meal opted for which haves four defined categories(BB, FB, HB, SC) and one undefined category (Categorical data)
#
# •	**country** : Country code of hotel
#
# •	**market_segment** : Which segment that customer belongs to (Categorical data)
#
# •	**distribution_chanel** : How the customer accessed the stay there are four categories corporate, direct, GDS, TA/TO and also some are undefined (Categorical data)
#
# •	**is_repeated_guest** : Shows whether customer is already visited or new (Categorical data)
#
# •	**previous_cancellation** : number of previously cancelation by customer
#
# •	**previous_booking_not_cancelled** : number of previously booked and stayed by customer
#
# •	**reserved_room_type** : Consists one among the 10 room types (Categorical data)
#
# •	**assigned_room_type** : Which contains type of room reserved (Categorical data)
#
# •	**booking_changes** : Count of changes made to booking
#
# •	**deposit_type** : Deposit type (Categorical data)
#
# •	**agent** : Booked through agent
#
# •	**days_in_waiting_list** : Number of days in waiting list
#
# •	**customer_type** : Categorical data contains the type of customer
#
# •	**customer_type** : Categorical data contains the type of customer
#
# •	**adr** : Average Daily rate
#
# •	**required_car_parking** : If car parking is required (Categorical data)
#
# •	**total_of_special_req** : Number of additional special requirements
#
# •	**reservation_status** : Reservation of status (Categorical data)
#
# •	**reservation_status_date** : Date of the specific status

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in list(booking_df.columns):
  print(f"No. of unique values in {i} is {booking_df[i].nunique()}.")
# Out:
# No. of unique values in hotel is 2.
# No. of unique values in is_canceled is 2.
# No. of unique values in lead_time is 479.
# No. of unique values in arrival_date_year is 3.
# No. of unique values in arrival_date_month is 12.
# No. of unique values in arrival_date_week_number is 53.
# No. of unique values in arrival_date_day_of_month is 31.
# No. of unique values in stays_in_weekend_nights is 17.
# No. of unique values in stays_in_week_nights is 35.
# No. of unique values in adults is 14.
# No. of unique values in children is 5.
# No. of unique values in babies is 5.
# No. of unique values in meal is 5.
# No. of unique values in country is 177.
# No. of unique values in market_segment is 8.
# No. of unique values in distribution_channel is 5.
# No. of unique values in is_repeated_guest is 2.
# No. of unique values in previous_cancellations is 15.
# No. of unique values in previous_bookings_not_canceled is 73.
# No. of unique values in reserved_room_type is 10.
# ...

# %% [markdown]
# ## **3.** ***Data Wrangling***

# %% [markdown]
# ### Data Cleaning

# %%
# Remove duplicates rows
booking_df.drop_duplicates(inplace = True)

# %%
# Drop is_canceled column as we have reservation status with similar data
booking_df.drop('is_canceled', axis = 1, inplace = True)

# %%
# Replace occurrences of the values 'Undefined' in the 'meal' column with 'No Meal
booking_df.replace({'meal': " 'Undefined', 'No Meal' "}, inplace = True)

# %%
# Handle missing values of children column by filling the missing values with 0
booking_df.fillna({'children':0}, inplace = True)

# %%
# Handle missing values of country column using mode
booking_df.fillna({'company': booking_df['country'].mode()[0]}, inplace = True)

# %%
# Drop distribution channel column as it is similar to market segment
booking_df.drop('distribution_channel', axis =1, inplace = True)

# %%
# Replace the value 0 and 1 in column 'is_repeated_guest' with 'No' and 'Yes'
booking_df.replace({'is_repeated_guest':{0:'No',1:'Yes'}}, inplace = True)

# %%
# Handling missing values of column 'agent' by filling it with 'No agent'
booking_df.fillna({'agent': 'No agent'}, inplace = True)

# %%
# Handling missing values of column 'company'
booking_df.fillna({'company':'No company'}, inplace = True)

# %%
# Combine arrival year, month and day to single column(arrival_date)
arrival_date = booking_df['arrival_date_year'].astype(str) + '-' + booking_df['arrival_date_month'] + '-' + booking_df['arrival_date_day_of_month'].astype(str)
booking_df['arrival_date'] = pd.to_datetime(arrival_date)

# %%
# Drop the arrival year, month and day columns as we created arrival_date column
booking_df.drop(['arrival_date_year', 'arrival_date_month', 'arrival_date_day_of_month'], axis = 1, inplace = True)

# %%
# Convert datatype of reservation status date to datetype
booking_df['reservation_status_date'] = pd.to_datetime(booking_df['reservation_status_date'])

# %%
# Check for the outliers in column "lead_time"
# Create a box plot of the 'lead_time' feature
sns.boxplot(x = 'lead_time', data = booking_df)

# Show the plot
plt.show()

# %%
# Dealing with outliers of lead time using IQR method
booking_df = booking_df[(booking_df.loc[:,'lead_time'] >= booking_df.loc[:,'lead_time'].quantile(0.05)) &
        (booking_df.loc[:,'lead_time'] <= booking_df.loc[:,'lead_time'].quantile(0.95))] #Removing the outlier

# %%
# Handling outliers in market segment
booking_df = booking_df[booking_df['market_segment'] != 'Undefined']

# %%
# Check for the outliers in column "adr"
# Create a box plot of the 'adr' feature
sns.boxplot(x = 'adr', data = booking_df)

# Show the plot
plt.show()

# %%
# Dealing with outliers of adr using IQR method
booking_df = booking_df[(booking_df.loc[:,'adr'] >= booking_df.loc[:,'adr'].quantile(0.05)) &
        (booking_df.loc[:,'adr'] <= booking_df.loc[:,'adr'].quantile(0.95))]

# %% [markdown]
# ###Data Aggregation

# %%
# Aggregate the 'lead_time' column by calculating the mean lead time for each reserved room type and sorting to find room with the highest mean lead time
room_type_avg_lead_time = booking_df.groupby("reserved_room_type").agg({"lead_time":"mean"}).rename(columns={"lead_time":"avg_lead_time"}).sort_values(by = "avg_lead_time", ascending = False).reset_index()

# Print the aggregated dataframe to show the average lead time for each reserved room type
room_type_avg_lead_time
# Out:
#   reserved_room_type  avg_lead_time
# 0                  B      94.294248
# 1                  E      75.965283
# 2                  D      74.982369
# 3                  C      71.861798
# 4                  G      67.559774
# 5                  A      64.209982
# 6                  F      62.342660
# 7                  H      59.707804
# 8                  L       0.000000
# 9                  P       0.000000

# %%
#Finding top meal category using mode function
top_meal_category = booking_df['meal'].mode()[0]

# print the top category meal
print(f"Most of the peoples are prefering '{top_meal_category}' category meal.")
# Out:
# Most of the peoples are prefering 'BB' category meal.

# %%
# Finding booking count countrywise
booking_count_countrywise = booking_df['country'].value_counts()
print("Top 5 countries based on booking count as follows :")

# print first 5 rows to show the booking counts for each top 5 countries
booking_count_countrywise.head()
# Out:
# Top 5 countries based on booking count as follows :
# country
# PRT    26162
# GBR     9335
# FRA     8637
# ESP     7144
# DEU     5023
# Name: count, dtype: int64

# %%
# Find the cancellation count for each market segment where the reservation status is either 'Canceled' or 'No-Show'
market_segment_cancellation_count = booking_df[(booking_df['reservation_status'] == 'Canceled') |
                                (booking_df['reservation_status'] == 'No-Show')].groupby('market_segment').agg({'reservation_status':'count'}).rename(columns = {'reservation_status':'cancellation_count'}).sort_values(by = 'cancellation_count', ascending = False).reset_index()

# Print the resulting dataframe to view cancellation counts for each market segment
print(market_segment_cancellation_count)
# Out:
#   market_segment  cancellation_count
# 0      Online TA               17094
# 1  Offline TA/TO                1775
# 2         Direct                1664
# 3         Groups                 930
# 4      Corporate                 503
# 5  Complementary                  88
# 6       Aviation                  45

# %%
# Group the dataset by 'market_segment' and 'reserved_room_type', then count the occurrences of each combination. Also, sort the results and drop duplicates
top_room_type = booking_df.groupby(['market_segment', 'reserved_room_type']).size().reset_index(name='room_type_count').sort_values(by = ['market_segment', 'room_type_count'], ascending = [True, False]).drop_duplicates(subset=['market_segment'], keep='first').reset_index()

# Drop the 'index' column from the dataframe
top_room_type.drop('index', axis = 1, inplace = True)

# Display the dataframe with the top room type for each market segment with their counts
top_room_type
# Out:
#   market_segment reserved_room_type  room_type_count
# 0       Aviation                  A              122
# 1  Complementary                  A              432
# 2      Corporate                  A             3759
# 3         Direct                  A             6121
# 4         Groups                  A             3462
# 5  Offline TA/TO                  A             9252
# 6      Online TA                  A            30371

# %%
# Group the data with cancellations by 'agent' column' and aggregate by cancellation count. Then, rename the column and sort the values by cancellation count
agent_cancellation = booking_df[booking_df['reservation_status'] != 'Check-Out'].groupby('agent').agg({'reservation_status':'count'}).rename(columns = {'reservation_status':'cancellation_count'}).sort_values(by = 'cancellation_count', ascending = False).reset_index()

# Remove rows where the 'agent' column has the value 'No agent'
agent_cancellation.drop(agent_cancellation[agent_cancellation['agent'] == 'No agent'].index, inplace = True)

# Filter the dataframe to keep only agents with more than 50 cancellations
agent_cancellation = agent_cancellation[agent_cancellation['cancellation_count']>50]

# Print the final dataframe with agents having more than 50 cancellations
agent_cancellation
# Out:
#     agent  cancellation_count
# 0     9.0               10913
# 1   240.0                4488
# 3    14.0                 567
# 4   250.0                 469
# 5     7.0                 425
# 6     8.0                 363
# 7   242.0                 217
# 8   241.0                 201
# 9     1.0                 188
# 10   83.0                 153
# 11    6.0                 127
# 12  314.0                 112
# 13   85.0                  95
# 14    3.0                  94
# 15   28.0                  85
# 16   15.0                  73
# 17   86.0                  54
# 18   40.0                  51
# 19  171.0                  51

# %%
# Group the data with cancellations by 'deposit_type' column' and aggregate by cancellation count. Then, rename the column and sort the values by cancellation count
deposit_cancellation = booking_df[booking_df['reservation_status'] != 'Check-Out'].groupby('deposit_type').agg({'reservation_status':'count'}).rename(columns = {'reservation_status':'cancellation_count'}).sort_values(by = 'cancellation_count', ascending = False).reset_index()

# Print the resulting dataframe containing the cancellation count for each deposit type
deposit_cancellation
# Out:
#   deposit_type  cancellation_count
# 0   No Deposit               21466
# 1   Non Refund                 610
# 2   Refundable                  23

# %%
# Group the required car parking data by 'reserved_room_type' and 'required_car_parking_spaces' and aggregate by count of 'required_car_parking_spaces'. Then remane the column and sort the values by 'required_car_parking_spaces' and count column
car_parking_room_type = booking_df[booking_df['required_car_parking_spaces'] != 0].groupby(['reserved_room_type','required_car_parking_spaces']).agg({'required_car_parking_spaces':'count'}).rename(columns = {'required_car_parking_spaces':'count'}).sort_values(by=['required_car_parking_spaces', 'count'], ascending=[True, False]).reset_index()

# Print the resulting dataframe with room type and requested parking spaces, along with the count
car_parking_room_type
# Out:
#    reserved_room_type  required_car_parking_spaces  count
# 0                   A                            1   3750
# 1                   D                            1   1265
# 2                   E                            1    964
# 3                   G                            1    391
# 4                   F                            1    373
# 5                   C                            1    175
# 6                   H                            1    162
# 7                   B                            1     38
# 8                   A                            2     13
# 9                   D                            2      4
# 10                  G                            2      4
# 11                  E                            2      2
# 12                  F                            2      2
# 13                  H                            2      1
# 14                  A                            3      3
# ...

# %%
# Group the data with cancellations by 'customer_type' column' and aggregate by cancellation count. Then, rename the column and sort the values by cancellation count
customer_type_cancellation = booking_df[booking_df['reservation_status'] != 'Check-Out'].groupby('customer_type').agg({'reservation_status':'count'}).rename(columns = {'reservation_status':'cancellation_count'}).sort_values(by = 'cancellation_count', ascending = False).reset_index()

# Print the resulting dataframe containing the cancellation count for each customer type
customer_type_cancellation
# Out:
#      customer_type  cancellation_count
# 0        Transient               20165
# 1  Transient-Party                1472
# 2         Contract                 425
# 3            Group                  37

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# 1. **Aggregated the lead time for reserved room type** -
#
# insight: Rooms of type 'B' tend to have a longer average lead time, so it's important to closely monitor these bookings. Consider reaching out to customers in advance to confirm their dates and ensure their reservations.
#
# 2. **Found the top meal category** -
#
# insight: The BB meal type is the most preferred, so if you're considering offering promotions on food, make BB the focal point. Additionally, encourage hotels to provide or emphasize this meal option to attract more customers.
#
# 3. **Booking count countrywise** -
#
# insight: PRT, GBR, FRA, ESP, and DEU are the top-performing countries. Strengthening partnerships with more hotels in these countries could significantly increase bookings and drive further growth.
#
# 4. **Aggregated cancellation count by each market segment** -
#
# insight: The Online TA market segment has a high number of cancellations. To address this, consider organizing meetings or workshops with these agents and implementing targeted actions or offering incentives to help reduce cancellations.
#
# 5. **market segment wise top performing room type** -
#
# insight: All market segments show a strong preference for A-type rooms, but availability is limited. To better meet customer demand and enhance retention, consider increasing the number of A-type rooms.
#
# 6. **Aggregated agent with cancellation** -
#
# insight: Agent 9.0 has the highest number of cancellations. Conduct an investigation to identify the root causes of the issue and address any potential problems.
#
# 7. **Comparing the cancellation with deposit type** -
#
# insight: The "No Deposit" option has a high cancellation rate. Consider implementing a refundable deposit policy, as bookings with refundable deposits tend to have lower cancellation rates.
#
# 8. **Aggregated the car parking and room type** -
#
# insight:
#
# *   Customers booking A-type rooms have the highest demand for car parking. As discussed earlier, ensure parking facilities are provided when building additional A-type rooms.
# *  Most customers only require a single parking slot, with very few needing more than one. To optimize costs, avoid overspending on parking spaces regardless of the number of rooms.
#
# 9. **Aggregated the customert type with the cancellation** -
#
# insight: Transient customers have a high cancellation rate. To retain them, consider offering special deals and complimentary refreshments. This could help reduce cancellations and improve customer satisfaction.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ###1) Univariate Analysis

# %% [markdown]
# #### chart - 1 - To Show Distribution of Room Types

# %%
# plot a bar chart to know the distribution of room types over booking
booking_df['reserved_room_type'].value_counts().plot(kind='bar')
plt.title('Distribution of Room Types')
plt.xlabel('Room Type')
plt.ylabel('Booking Count')
plt.show()

# %% [markdown]
# ######1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts can be sorted by height, which allows for quick identification of the most and least popular room types, aiding in prioritization.
#
# Bar charts are intuitive and easy for audiences to understand. Viewers can quickly grasp the distribution of room types without needing extensive background knowledge.

# %% [markdown]
# ######2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 'A' type rooms are the most booked whereas 'L' and 'P' are least.

# %% [markdown]
# ######3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# "A" type rooms are the most boooked type, business needs to ensure enough rooms are available in such category, if not need to take initiative to build new rooms.
#
# "L" and "p" are the least booked types, try to invest less on those type rooms in future. Providing discounts for such type rooms leads to gain more customers.

# %% [markdown]
# #### chart - 2 - To Show Distribution of Reservation Status

# %%
# plot a pie chart for reservation status
plt.pie(booking_df['reservation_status'].value_counts(), labels = booking_df['reservation_status'].value_counts().index, autopct='%1.1f%%', startangle = 90)
plt.title('Distribution of Reservation Status')
plt.show()

# %% [markdown]
# ######1. Why did you pick the specific chart?

# %% [markdown]
# As this holds limited number of categories and piechart helps in ease of visualization to observe contribution of each categories quickly.

# %% [markdown]
# ######2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Over 27% peoples not visited as per the booking.

# %% [markdown]
# ######3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This shows that there is some issue with business that we need to focus on and take actions to resolve those issues. Also taking feedback survey while cancelling the booking helpfull for business to know what actually customer needs.
#
# Eventhough 73% is a good number Business needs to maintain this streak by analysing and providing the needfulls.

# %% [markdown]
# ####chart 3 - To Show Contribution of Each Customer Type

# %%
# create countplot for distribution of customer type
sns.countplot(data = booking_df, x = 'customer_type')
plt.title('Distribution of Customer Type')
plt.xlabel('Customer Type')
plt.ylabel('Booking count')
plt.show()

# %% [markdown]
# ######1. Why did you pick the specific chart?

# %% [markdown]
# Countplots are designed for categorical data, making them ideal for displaying the frequency of distinct customer types.

# %% [markdown]
# ######2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Transient is the highest performing customer category, while Group is the lowest performing category.

# %% [markdown]
# ######3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Providing added perks such as meal coupons and buffet breakfasts for the transient group helps maintain their high engagement and sustaining their strong performance.
#
# On the other hand, the low performance of the Group category may stem from factors such as inadequate room size. The business should focus on attracting more group bookings, as this segment has significant financial potential. Collaborating with travel agents who offers group tour packages could be a strategic approach to boost performance in this category.

# %% [markdown]
# ####chart - 4 - To Show distribution of lead time

# %%
# plot histogram for lead time distribution
sns.histplot(data = booking_df, x = 'lead_time', bins=20)
plt.title('Distribution of Lead Time')
plt.xlabel('Lead Time')
plt.ylabel('Booking Count')
plt.xticks(range(0, 300, 25))
plt.show()

# %% [markdown]
# ######1. Why did you pick the specific chart?

# %% [markdown]
# As we are ploting for a continuous data variable hist plot suits better and helps on getting distributions clearly.

# %% [markdown]
# ######2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most peoples are booking at last minute only.

# %% [markdown]
# ######3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We need to promote and give offers for early booking, need to check whether there is any glitches on our website while booking and make the website user friendly, compare with competitor's websites and try to implement positive feedbacks present there.

# %% [markdown]
# ####chart - 5 - wordcloud Visualization of country

# %%
# wordcloud to show frquency of country

# create a dict that stores each country and it's frequency
country_dict = booking_df['country'].value_counts().to_dict()

# plot a wordcloud
wordcloud = WordCloud(width = 400, height = 300, min_font_size = 10, background_color='beige').generate_from_frequencies(country_dict)
plt.figure(figsize = (10, 5))
plt.imshow(wordcloud, interpolation = 'antialiased')
plt.axis('off')
plt.show()

# %% [markdown]
# ######1. Why did you pick the specific chart?

# %% [markdown]
# We have several category in this variable and it adds up visually intresting effect which encourages busines's interactivity on this project.

# %% [markdown]
# ######2. What is/are the insight(s) found from the chart?

# %% [markdown]
# PRT, GBR, FRA, ESP, DEU are top performing countries

# %% [markdown]
# ######3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This trend may be due to the countrie's tourism or industrial cultures, In order to maintain this trend the business may offer some discounts for top performing agents as they plays significant roles to attain this.
#
# Also finding good agents and advertising on least popular countries results in good impact.

# %% [markdown]
# ###2) Bivariate Analysis

# %% [markdown]
# #### chart - 6 - Heat map visualization of reserved room type and assigned room type

# %%
# plot a heatmap to show how effectively rooms are allocated

# create a matrix to store percentage of room allocations
room_booking_matrix = pd.crosstab(booking_df['reserved_room_type'], booking_df['assigned_room_type'], normalize = 'index' )*100

# plot a heatmap
plt.figure(figsize=(10,5))
sns.heatmap(room_booking_matrix, annot = True, fmt = '.2f', cmap = 'twilight')
plt.title('Room Allocation Heatmap')
plt.plot()
# Out:
# []

# %% [markdown]
# ######1. Why did you pick the specific chart?

# %% [markdown]
# it provides a clear, color-coded representation of the frequency of each combination. This allows us to quickly identify patterns and easier to interpret.

# %% [markdown]
# ######2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This analysis reveals that 20% of room type A reservations are being reassigned to a different room type. This insight highlights a potential gap between customer expectations and actual room allocation particularly in premium category rooms.

# %% [markdown]
# ######3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  If customers receive the room type they reserved, especially when it involves premium or in-demand rooms, it can lead to increased revenue from premium services.
#
#
#  If this issue is left unaddressed, customers who reserve a specific room type may feel dissatisfied when they are assigned a different room type. This could lead to negative reviews, reduced customer loyalty, and loss of repeat business.

# %% [markdown]
# #### Chart - 7 - Bar chart to get relation between room type and average lead time

# %%
# plot a Bar chart to get relation between room type and their average lead time

# find out mean lead time for each room type
avg_lead_time = booking_df.groupby('reserved_room_type')['lead_time'].mean()

# plot a bar chart
plt.bar(avg_lead_time.index, avg_lead_time.values)
plt.title('Average Lead Time by Room Type')
plt.xlabel('Room Type')
plt.ylabel('Average Lead Time (Days)')
plt.show()

# %% [markdown]
# ######1. Why did you pick the specific chart?

# %% [markdown]
# As this comparison between a categorical and numerical variables Bar Chart plays good role in this.

# %% [markdown]
# ######2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Room type B is the type which haves high leadtime over 3 months, L and P haves the lowest, all others are having average around 60-80 days

# %% [markdown]
# ######3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# As customers tend to book three months in advance, consider keeping the booking window open for up to six months.
#
# This approach can help minimize long waitlists, preventing negative perceptions that the website lacks sufficient rooms and is out of stock well in advance.

# %% [markdown]
# #### Chart - 8 - Box plot to show the relation between reservation status and lead time

# %%
# plot a box plot to get relation between reservation status and lead time
sns.boxplot(x = 'reservation_status', y= 'lead_time', data = booking_df, hue = 'reservation_status')
plt.title('Lead Time vs Reservation Status')
plt.xlabel('Reservation Status')
plt.ylabel('Lead Time (days)')
plt.show()

# %% [markdown]
# ######1. Why did you pick the specific chart?

# %% [markdown]
# Comparing a categorical variable over continuous variable so Box plot gives appropriate visaulization.

# %% [markdown]
# ######2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Increase in Lead time results on cancellation.

# %% [markdown]
# ######3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Try to get in touch with customers with high lead time by providing whatsapp advertisements like what are the things to do at the destination, attractions present there.
#
# Requesting to fill a quick feedback form while cancelling may hellpfull to know what customers actually thinking and try to avoid those things happen.

# %% [markdown]
# #### chart - 9 - Grouped Bar chart to show Booking and reservation status trend for Top 10 countries

# %%
# create a Bar chart that shows how much bookings are done, checked out, cancelled and no show status for each country

# Arrange the data for ploting
status_count_per_country = booking_df.groupby(['country', 'reservation_status']).size().unstack(fill_value=0).sort_values(by='Canceled', ascending=False)
status_count_per_country['Total_bookings'] = status_count_per_country['Canceled'] + status_count_per_country['Check-Out'] + status_count_per_country['No-Show']
status_count_per_country = status_count_per_country[['Total_bookings', 'Check-Out', 'Canceled', 'No-Show']].head(10)

# plot the chart
status_count_per_country.plot(kind = 'bar')
plt.title('Booking Status by Country - Top 10')
plt.xlabel('Country')
plt.ylabel('Count')
plt.legend(title='Reservation Status')
plt.show()

# %% [markdown]
# ######1. Why did you pick the specific chart?

# %% [markdown]
# Each country has multiple bars representing different categories and we comparing this over count so Grouped Bar chart is the best option.

# %% [markdown]
# ######2. What is/are the insight(s) found from the chart?

# %% [markdown]
# All countries have considerable amount of cancellation with respective chech outs.

# %% [markdown]
# ######3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  By understanding the reasons behind the cancellation with respect to each country, the business can implement targeted strategies to improve customer satisfaction, streamline the booking process, and can reduce cancellations which leads to increase in revenue.
#
#  If the cancellation rates are not addressed, they could result in financial losses as each cancellation represents missed revenue opportunities. There can be a time where the cancellation rate get higher than the checkout if not addressed

# %% [markdown]
# #### chart - 10 - Pie chart to show distribution of reservation type over deposit type

# %%
# plot a pie chart to show distribution of cancellation over deposit type

# prepare the data for ploting
deposit_cancellation = booking_df[booking_df['reservation_status'] != 'Check-Out'].groupby('deposit_type').agg({'reservation_status':'count'}).rename(columns = {'reservation_status':'cancellation_count'}).sort_values(by = 'cancellation_count', ascending = False).reset_index()

# prepare legends and size representation for thw plot
legends = deposit_cancellation['deposit_type']
sizes = deposit_cancellation['cancellation_count']

# plot the chart
plt.figure(figsize= (7,5))
plt.pie(sizes, autopct='%1.1f%%', startangle=45, explode = (0, 0, 0.5), colors=['#ff9999','#66b3ff','green'])
plt.legend(legends)
plt.axis('equal')
plt.title('cancellation vs deposit type')
plt.show()

# %% [markdown]
# ######1. Why did you pick the specific chart?

# %% [markdown]
# Pie chart helps in getting distributions over categories easily.

# %% [markdown]
# ######2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The "No Deposit" option has a high cancellation rate and refundable option has less cancellation than non-refundable.

# %% [markdown]
# ######3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Consider adopting a refundable deposit policy, as bookings with refundable deposits generally experience very lower cancellation rates. By providing incentives for customers to select refundable options, the business can decrease overall cancellations, improve customer satisfaction, and stabilize revenue.

# %% [markdown]
# #### chart - 11 - Line chart to show the distribution of booking numbers over months

# %%
# plot a line chart to show trend of booking over months

# prepare data for ploting
monthly_counts = booking_df.groupby(booking_df['arrival_date'].dt.month)['reservation_status'].size()

# plot the chart
plt.figure(figsize=(7,5))
monthly_counts.plot(kind = 'line', marker = 'o')
plt.xlim(0.5, 12.5)
plt.xlabel('Month')
plt.ylabel('Number of Bookings')
plt.title('Monthly Distribution of Booking Numbers')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.show()

# %% [markdown]
# ######1. Why did you pick the specific chart?

# %% [markdown]
# Line charts are ideal for tracking how values evolve over a continuous period, making them perfect for visualizing trends.

# %% [markdown]
# ######2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Trend gradually starts increasing from February, peaks at August,  suddent downturn occur in september and remains flat untill january.

# %% [markdown]
# ######3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Since summer is the peak travel season, our business thrives during this period. To stay on the right track, it's crucial to maintain sustainability by ensuring more hotels and customer service executives are available during these busy months.
#
# On the other hand, winter trends indicate a need for attention. Focus on increasing advertising efforts and promoting winter activities. Offering complimentary activity kits at hotels can be an effective way to attract more guests and boost engagement during the winter season.

# %% [markdown]
# #### chart - 12 - Box Plot - Average Daily Rate vs Assigned Room Type

# %%
# box plot to show the relation between adr and room type

# Sort values
sorted_values = booking_df['assigned_room_type'].sort_values().unique()

# code box plot
plt.figure(figsize=(7,5))
sns.boxplot(x = 'assigned_room_type', y = 'adr', data = booking_df, order = sorted_values, hue = 'assigned_room_type')
plt.xlabel('Assigned Room Type')
plt.ylabel('Average Daily Rate (ADR)')
plt.title('Average Daily Rate by Room Type')
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# We're comparing multiple categories over adr(numeric data), So box plot gives clear picture by providing seperate box for each category. Also here we're analyzing for cost related thing so instead of averaging values box gives actually where business haves high potential by exploding the outliers.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# F type rooms holds high potential average while I is the lowest.
#
# Premium room segment's contribution is low in point of adr.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Understanding that Room Type F has a high ADR potential allows the business to allocate more resources, focus promotions, and optimize bookings for this room type to maximize revenue.
#
# Also should target the right customer base where we can promote the premium room types.
#
# If premium rooms are not performing well, the business is missing out on opportunities to upsell to higher-paying customers, which could negatively impact long-term profitability.

# %% [markdown]
# ###3) Multivariate Analysis

# %% [markdown]
# #### chart - 13 - Scatter plot for showing relation between ADR, Days in waiting list and Hotel type

# %%
# plot the scatter plot
sns.scatterplot(data = booking_df, x = 'adr', y = 'days_in_waiting_list', hue = 'hotel')
plt.title('Relationship between waiting list and ADR with Hotel type as hue')
plt.xlabel('adr')
plt.ylabel('days_in_waiting_list')
plt.show()

# %% [markdown]
# ######1. Why did you pick the specific chart?

# %% [markdown]
# Plotting relation two continuous variable with hotel type as hue, so scatter plot provides asthetic and visually pleasing chart.

# %% [markdown]
# ######2. What is/are the insight(s) found from the chart?

# %% [markdown]
# High waiting list for resort hotels.
#
# Lack of Resort hotels at mid and premium category.
#
# Low waiting list for city hotels in low and high ADR category.

# %% [markdown]
# ######3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# High waiting list for resort hotels with lower prices suggests strong demand. The business could consider increasing the availability of resort hotel rooms, especially during peak seasons, or adjust pricing strategies to better match demand. This could help reduce waiting times and increase occupancy, improving overall customer satisfaction. otherwise high waiting list could negatively impact the customer experience if bookings are delayed or unavailable.
#
#
# The lack of waiting lists for City hotels at lower and premium category suggests that there may be lack of  increasing demand. The business could introduce targeted promotions, enhance the guest experience, or offer additional services to attract more bookings, especially during off-peak times.

# %% [markdown]
# #### chart - 14 - Correlation heatmap

# %%
# Correlation Heatmap visualization code
numerical_cols = booking_df.select_dtypes(include=['int64', 'float64'])
plt.figure(figsize=(10,7))
sns.heatmap(numerical_cols.corr(), annot = True, fmt = '.2f')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ######1. Why did you pick the specific chart?

# %% [markdown]
# Heatmap helps in identifying relationship and patterns when comparing with large set of categories.

# %% [markdown]
# ######2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This plot gives relations between all numerical values present in the given data.

# %% [markdown]
# ######3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This plot helps them to know any relations between two variables quickly and helps in providing insights if they have any stratergical approaches which they don't want to disclose to peoples.

# %% [markdown]
# #### chart - 15 - Pair Plot

# %%
# plot a pair plot to show distribution between waiting list, adr and lead time
cols = booking_df[['lead_time', 'adr', 'days_in_waiting_list', 'reservation_status']]
sns.pairplot(cols, diag_kind = 'kde', hue = 'reservation_status')
plt.show()

# %% [markdown]
# ######1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot is an effective tool for identifying the best set of features to explain relationships between variables or to distinguish clusters in the data. It can also aid in forming simple classification models by visually highlighting separations or linear relationships within the dataset.
#
# I used a pair plot to analyze patterns and relationships between features. It offers a graphical representation similar to a correlation matrix, but provides more detailed insights by visually displaying how variables interact with each other.

# %% [markdown]
# ######2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Lead time gives direct proportion with waiting list.
#
# Longer waiting list and lead time leads to cancellation at several points.

# %% [markdown]
# ######3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Eventhough customers approaching earlier, waiting list is applied on them, Which gives clear image that business need to take care on this type of bookings, Because graph shows that longer waiting list leads to high cancellations.
#
# Business may spend some amount on placing representatives to monitor and provide inpersonal advertisements through digital mediums like whatsapp messengers will increase their connection and motivates them for better relationship with the business.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# ***Actions required for improving revenue:***
#
# 1) Offering BB type meals to Transients which is the most popular meal type reduces their high cancellations.
#
# 2) Introducing new hotels at PRT, GBR. FRA, ESP, DEU countries helps in matching the demand.
#
# 3) Invest in improving customer service and amenities to enhance customer's satisfaction.
#
# 4) Reduce spending on parkings as low number of people are in need and most of them too need one or two.
#
# 5) Providing inpersonal and polite assistance to persons booking at last minute as most of the bookings are done at last minute.
#
# 6) Promote city hotels during low demand periods i.e, winters by advertising winter activities.
#
# 6) Placing more executives and monitoring website actions over summer is more important due to high demand.
#
# 7) Placing dynamic price will be stratergic approach.
#
# ***Solutions to reduce cancellation:***
#
# 1) "A" category rooms need to be established to encounter demand and waiting list.
#
# 2) Changing deposit type from no deposit to refundable.
#
# 3) Need to provide inpersonal interactions with tansient customers and offering complimentary breakfasts.
#
# 4) Need to provide rooms as per the customer demand esspecially "A" category rooms.
#
# 5) Resort hotels need to be provided high in number to reduce demand and cancellations due to waiting list.
#
# 6) Requesting Online TA market segment to provide discounts to customers will reduce cancellation.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# • Need additional hotels in order to reduce waiting list.
#
# • Approach with refundable deposit instead of no deposit.
#
# • Should find the strategies to promote premium rooms as they have less booking counts.
#
# • Need to ensure requested rooms are allocated.
#
# • Transients need to be monitored as they are top performing and cancelling category.
#
# • Winters need more discounts and advertisements.
#
# • Strengthen partnerships with high-performing countries.
